# %%
from langchain.vectorstores import Chroma

# %%
# provide absolute path pointing the vectore sore

# %%
# - copy as path from the usefulcomponents/vectorstore/yourfilename

db_path="/Users/c/Documents/vectorstores/ai_insights_1680197198767"

# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

from embedding_model import get_embedding_model
embd=get_embedding_model()

# %%
db = Chroma(persist_directory=db_path, embedding_function=embd)

# %%
data = db.get(
    include=["documents", "metadatas", "embeddings"]
)

print(data.keys())
# Out:
# dict_keys(['ids', 'embeddings', 'documents', 'uris', 'included', 'data', 'metadatas'])

# %%
data["documents"][10:15]
# Out:
# []

# %%
import numpy as np

embeddings = np.array(data["embeddings"])
print("Embedding shape:", embeddings.shape)
# Out:
# Embedding shape: (0,)

# %%
len(data["embeddings"])
# Out:
# 0

# %%
len(data["embeddings"][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 len(data["embeddings"][0])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
data["embeddings"][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 data["embeddings"][0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import pandas as pd

df = pd.DataFrame({
    "id": data["ids"],
    "document": data["documents"],
    "metadata": data["metadatas"]
})

df.head(10)
# Out:
# Empty DataFrame
# Columns: [id, document, metadata]
# Index: []

# %%
df.iloc[5,1]
# Out:
# 'We wrote this book because we are excited about the emergence of\nAL as an integrated science, Here, concepts of AI are explained with\nexamples. We develop the science of AI together with its engineering\napplications. We must build the science on sold foundations; we present\nthe foundations, and give some examples of the complexity required to\n‘build useful intelligent systems.\n\nAAI research is expanding so rapidly now that the volume of\npotential new text material is vast. However, research teaches us not only\n‘what works but also what does not work so wel, allowing us to be highly\nselective, We have included material on machine learning techniques that\nhave proven successful.'
